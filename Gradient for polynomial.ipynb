# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# f(x)= 36/7x^2 + 4x + 3
# f'(x)= 72/7x + 4

# %%
fun = []
funx = []
alpha = 0.00000001
epsilon = 0.001
j = 0
New_value = []
old_values = np.random.randn(1,6)
coefficients =np.array([[4,4,9],[2,4,9],[4,10,18],[7,16,27],[19,50,96],[108,220,279]])

while (True):
    
    terms = []
    for i in range (0,6):
        terms.append([1, old_values[0][i], old_values[0][i]**2])
    terms = np.array(terms)

    result=coefficients*terms
    result=np.sum(result,axis=1)
    result = result.reshape(6,1)
    
    New_value= old_values - alpha*result.T
        
    function1=4*old_values[0][0] + old_values[0][0]**2 + 3*old_values[0][0]**3 + 2*old_values[0][1] + 2*old_values[0][1]**2 + 3*old_values[0][1]**3 + 4*old_values[0][2] + 5*old_values[0][2]**2 + 6*old_values[0][2]**3 + old_values[0][3] + 8*old_values[0][3]**2 + 9*old_values[0][3]**3 + 19*old_values[0][4] + 25*old_values[0][4]**2 + 37*old_values[0][4]**3 + 108*old_values[0][5] + 110*old_values[0][5]**2 + 93*old_values[0][5]**3
    
    function2=4*New_value[0][0] + New_value[0][0]**2 + 3*New_value[0][0]**3 + 2*New_value[0][1] + 2*New_value[0][1]**2 + 3*New_value[0][1]**3 + 4*New_value[0][2] + 5*New_value[0][2]**2 + 6*New_value[0][2]**3 + New_value[0][3] + 8*New_value[0][3]**2 + 9*New_value[0][3]**3 + 19*New_value[0][4] + 25*New_value[0][4]**2 + 37*New_value[0][4]**3 + 108*New_value[0][5] + 110*New_value[0][5]**2 + 93*New_value[0][5]**3
    
    fun.append(function1)
    j = j+1  
    funx.append(j)
    
    #print("The value of Function at iteration number {} is {}".format(j,function1))
    
    if (abs(function1-function2))< epsilon or np.isnan(function1)==True:
        break
    del old_values
    old_values = New_value.copy()

plt.plot(funx,fun)

# %%
fun = []
funx = []
alpha = 0.000001
epsilon = 0.001
j = 0
New_value = []
old_values = np.random.randn(1,6)
coefficients =np.array([[4,4,9],[2,4,9],[4,10,18],[7,16,27],[19,50,96],[108,220,279]])

while (True):
    
    terms = []
    for i in range (0,6):
        terms.append([1, old_values[0][i], old_values[0][i]**2])
    terms = np.array(terms)

    result=coefficients*terms
    result=np.sum(result,axis=1)
    result = result.reshape(6,1)
    
    New_value= old_values - alpha*result.T
        
    function1=4*old_values[0][0] + old_values[0][0]**2 + 3*old_values[0][0]**3 + 2*old_values[0][1] + 2*old_values[0][1]**2 + 3*old_values[0][1]**3 + 4*old_values[0][2] + 5*old_values[0][2]**2 + 6*old_values[0][2]**3 + old_values[0][3] + 8*old_values[0][3]**2 + 9*old_values[0][3]**3 + 19*old_values[0][4] + 25*old_values[0][4]**2 + 37*old_values[0][4]**3 + 108*old_values[0][5] + 110*old_values[0][5]**2 + 93*old_values[0][5]**3
    
    function2=4*New_value[0][0] + New_value[0][0]**2 + 3*New_value[0][0]**3 + 2*New_value[0][1] + 2*New_value[0][1]**2 + 3*New_value[0][1]**3 + 4*New_value[0][2] + 5*New_value[0][2]**2 + 6*New_value[0][2]**3 + New_value[0][3] + 8*New_value[0][3]**2 + 9*New_value[0][3]**3 + 19*New_value[0][4] + 25*New_value[0][4]**2 + 37*New_value[0][4]**3 + 108*New_value[0][5] + 110*New_value[0][5]**2 + 93*New_value[0][5]**3
    
    fun.append(function1)
    j = j+1  
    funx.append(j)
    
    print("The value of Function at iteration number {} is {}".format(j,function1))
    
    if (abs(function1-function2))< epsilon or np.isnan(function1)==True:
        break
    del old_values
    old_values = New_value.copy()

plt.plot(funx,fun)
# Out:
# The value of Function at iteration number 1 is -26.457749786023413
# The value of Function at iteration number 2 is -26.471283668399924
# The value of Function at iteration number 3 is -26.484814426472145
# The value of Function at iteration number 4 is -26.498342061887136
# The value of Function at iteration number 5 is -26.511866576291027
# The value of Function at iteration number 6 is -26.525387971329085
# The value of Function at iteration number 7 is -26.538906248645606
# The value of Function at iteration number 8 is -26.55242140988403
# The value of Function at iteration number 9 is -26.565933456686835
# The value of Function at iteration number 10 is -26.5794423906956
# The value of Function at iteration number 11 is -26.59294821355102
# The value of Function at iteration number 12 is -26.60645092689284
# The value of Function at iteration number 13 is -26.61995053235995
# The value of Function at iteration number 14 is -26.633447031590258
# ...
